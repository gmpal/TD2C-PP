# %%
#avoids the need for users to install TD2C as a package
import sys
sys.path.append('../../')

# %%
import pickle
import pandas as pd
import numpy as np
import os

# Imports for plotting and statistical tests
import matplotlib
matplotlib.use('agg') # Use non-interactive backend for saving files
import matplotlib.pyplot as plt
import operator
import math
from scipy.stats import wilcoxon, friedmanchisquare
import networkx

# Imports for metrics
from sklearn.metrics import precision_score, recall_score, f1_score, balanced_accuracy_score, accuracy_score

# =============================================================================
# 1. SETUP AND CONFIGURATION
# =============================================================================
from src.td2c.benchmark.utils import draw_cd_diagram

THRESHOLD = 0.309

OUTPUT_PATH_CD = "CD_PLOTS/"
os.makedirs(OUTPUT_PATH_CD, exist_ok=True)

ORDER_SAVING_RESULTS = [
    'var', 'varlingam', 'pcmci', 'mvgc', 'pcmci_gpdc',
    'granger', 'dynotears', 'td2c'
]

DISPLAY_NAMES = {
    'var': 'VAR', 'varlingam': 'VARLINGAM', 'pcmci': 'PCMCI', 'mvgc': 'MVGC',
    'pcmci_gpdc': 'PCMCI-GPDC', 'granger': 'GRANGER', 'dynotears': 'DYNOTEARS', 'td2c': 'TD2C'
}

plt.rcParams['font.family'] = 'DejaVu Sans'  # Use available font


datasets_name = ['TEST']
for dataset_name in datasets_name:
    file_path = f'data/causal_dfs/causal_dfs_{dataset_name}.pkl'
    print(f"--- Creating Original CD Plot for {dataset_name} ---")

    # --- Load Data ---
    with open(file_path, 'rb') as f:
        loaded_data = pickle.load(f)
    method_results_tuple = loaded_data[:-1]
    true_causal_dfs_dict = loaded_data[-1]

    # --- Calculate Precision scores for each run using pre-computed predictions ---
    run_ids = sorted(true_causal_dfs_dict.keys())

    metrics_function_dict = {'precision': precision_score,
                                'recall': recall_score,
                                'f1': f1_score,
                                'balanced_accuracy': balanced_accuracy_score,
                                'accuracy': accuracy_score}

    for metric, metric_function in metrics_function_dict.items():
        per_run_scores = []
        for run_id in run_ids:
            y_true_run = true_causal_dfs_dict[run_id]['is_causal'].astype(int)

            for i, method_dfs_dict in enumerate(method_results_tuple):
                internal_name = ORDER_SAVING_RESULTS[i]
                
                if method_dfs_dict is None or run_id not in method_dfs_dict:
                    continue

                if internal_name == 'td2c':
                    y_proba_run = method_dfs_dict[run_id]['probability'].astype(float)
                    y_pred_run = (y_proba_run > THRESHOLD).astype(int)
                else:
                    y_pred_run = method_dfs_dict[run_id]['is_causal'].astype(int)
                
                if metric == 'precision' or metric == 'recall' or metric == 'f1':
                    score = metric_function(y_true_run, y_pred_run, zero_division=np.nan)
                elif metric == 'balanced_accuracy' or metric == 'accuracy':
                    score = metric_function(y_true_run, y_pred_run)
                
                per_run_scores.append({
                    'Model': DISPLAY_NAMES[internal_name],
                    'dataset_name': f"{dataset_name}_{run_id}",
                    'Score': score, # The score for this run
                })
        
        # --- Create a DataFrame suitable for the CD plot function ---
        scores_df = pd.DataFrame(per_run_scores)
        
        # --- Generate the CD plot for Precision ---
        print("\nGenerating Precision CD plot...")
        output_path = f"{OUTPUT_PATH_CD}/cd_{dataset_name}_{metric}.png"
        draw_cd_diagram(
            path=output_path,
            df_perf=scores_df,
        )

    print("\nScript finished successfully.")
# Out:
# --- Creating Original CD Plot for TEST ---
#
# Generating Precision CD plot...
# ['VAR' 'VARLINGAM' 'PCMCI' 'MVGC' 'PCMCI-GPDC' 'GRANGER' 'DYNOTEARS'
#  'TD2C']
#         Model  count
# 0   DYNOTEARS   1080
# 1     GRANGER   1080
# 2        MVGC   1080
# 3       PCMCI   1080
# 4  PCMCI-GPDC   1080
# 5        TD2C   1080
# 6         VAR   1080
# 7   VARLINGAM   1080
# [[       nan        nan        nan ...        nan        nan        nan]
#  [0.14285714 0.23529412 0.         ... 0.         0.         0.11764706]
#  [0.51724138 0.62962963 1.         ... 1.         1.         0.6       ]
#  ...
#  [0.53571429 0.61538462 0.60869565 ... 0.71428571 0.5        0.39130435]
#  [0.5        0.8        1.         ... 0.         0.         0.57142857]
#  [0.47826087 0.40540541 0.68421053 ... 0.83333333 0.77777778 0.375     ]]
# DYNOTEARS     119.0
# GRANGER         7.0
# MVGC          100.0
# PCMCI          93.0
# PCMCI-GPDC    136.0
# TD2C          308.0
# VAR           119.0
# VARLINGAM      22.0
# dtype: float64
# GRANGER       6.474359
# VAR           4.836945
# VARLINGAM     4.425770
# MVGC          3.654693
# PCMCI         3.496741
# PCMCI-GPDC    3.414725
# TD2C          2.818981
# DYNOTEARS     2.242671
# dtype: float64
# ('DYNOTEARS', 'GRANGER', nan, False)
# ('DYNOTEARS', 'MVGC', nan, False)
# ('DYNOTEARS', 'PCMCI', nan, False)
# ('DYNOTEARS', 'PCMCI-GPDC', nan, False)
# ('DYNOTEARS', 'TD2C', nan, False)
# ('DYNOTEARS', 'VAR', nan, False)
# ('DYNOTEARS', 'VARLINGAM', nan, False)
# ('GRANGER', 'MVGC', nan, False)
# ('GRANGER', 'PCMCI', nan, False)
# ('GRANGER', 'PCMCI-GPDC', nan, False)
# ('GRANGER', 'TD2C', nan, False)
# ('GRANGER', 'VAR', nan, False)
# ('GRANGER', 'VARLINGAM', nan, False)
# ('MVGC', 'PCMCI', nan, False)
# ('MVGC', 'PCMCI-GPDC', nan, False)
# ('MVGC', 'TD2C', nan, False)
# ('MVGC', 'VAR', nan, False)
# ('MVGC', 'VARLINGAM', nan, False)
# ('PCMCI', 'PCMCI-GPDC', nan, False)
# ('PCMCI', 'TD2C', nan, False)
# ('PCMCI', 'VAR', nan, False)
# ('PCMCI', 'VARLINGAM', nan, False)
# ('PCMCI-GPDC', 'TD2C', nan, False)
# ('PCMCI-GPDC', 'VAR', nan, False)
# ('PCMCI-GPDC', 'VARLINGAM', nan, False)
# ('TD2C', 'VAR', nan, False)
# ('TD2C', 'VARLINGAM', nan, False)
# ('VAR', 'VARLINGAM', nan, False)
# Index(['GRANGER', 'VAR', 'VARLINGAM', 'MVGC', 'PCMCI', 'PCMCI-GPDC', 'TD2C',
#        'DYNOTEARS'],
#       dtype='object')
# [0, 1, 2, 3, 4, 5, 6, 7]
#
# Generating Precision CD plot...
# ['VAR' 'VARLINGAM' 'PCMCI' 'MVGC' 'PCMCI-GPDC' 'GRANGER' 'DYNOTEARS'
#  'TD2C']
#         Model  count
# 0   DYNOTEARS   1080
# 1     GRANGER   1080
# 2        MVGC   1080
# 3       PCMCI   1080
# 4  PCMCI-GPDC   1080
# 5        TD2C   1080
# 6         VAR   1080
# 7   VARLINGAM   1080
# [[0.         0.         0.         ... 0.         0.         0.        ]
#  [0.1875     0.22222222 0.         ... 0.         0.         0.22222222]
#  [0.9375     0.94444444 0.9375     ... 1.         1.         1.        ]
#  ...
#  [0.9375     0.88888889 0.875      ... 1.         1.         1.        ]
#  [0.1875     0.22222222 0.0625     ... 0.         0.         0.44444444]
#  [0.6875     0.83333333 0.8125     ... 1.         0.875      1.        ]]
# DYNOTEARS      21.0
# GRANGER         0.0
# MVGC           25.0
# PCMCI           2.0
# PCMCI-GPDC     11.0
# TD2C          559.0
# VAR             0.0
# VARLINGAM      16.0
# dtype: float64
# GRANGER       6.635185
# DYNOTEARS     6.443519
# VAR           6.416667
# PCMCI-GPDC    4.086111
# PCMCI         3.616204
# VARLINGAM     3.425000
# MVGC          3.374074
# TD2C          2.003241
# dtype: float64
# ('GRANGER', 'TD2C', 1.1745889611671249e-178, True)
# ('TD2C', 'VAR', 2.374562298077519e-178, True)
# ('DYNOTEARS', 'TD2C', 1.134013987996683e-175, True)
# ('VAR', 'VARLINGAM', 3.7941556573975062e-171, True)
# ('GRANGER', 'VARLINGAM', 2.631051846486299e-167, True)
# ('PCMCI', 'VAR', 8.640207828247548e-162, True)
# ('MVGC', 'VAR', 1.7204094878285772e-160, True)
# ('GRANGER', 'MVGC', 8.691916525481803e-159, True)
# ('PCMCI-GPDC', 'VAR', 2.2726724619766114e-158, True)
# ('GRANGER', 'PCMCI', 2.4790450700959705e-157, True)
# ('GRANGER', 'PCMCI-GPDC', 1.2269403992296982e-154, True)
# ('DYNOTEARS', 'VARLINGAM', 5.202675467443945e-141, True)
# ('PCMCI-GPDC', 'TD2C', 1.0826289520924305e-109, True)
# ('DYNOTEARS', 'MVGC', 3.384554228924158e-104, True)
# ('DYNOTEARS', 'PCMCI', 2.323077815166946e-99, True)
# ('PCMCI', 'TD2C', 2.8961303880730187e-94, True)
# ('DYNOTEARS', 'PCMCI-GPDC', 1.2881492776474704e-91, True)
# ('TD2C', 'VARLINGAM', 1.3183523569349199e-79, True)
# ('MVGC', 'TD2C', 1.934047738069939e-79, True)
# ('MVGC', 'PCMCI-GPDC', 4.316401931903859e-37, True)
# ('PCMCI-GPDC', 'VARLINGAM', 2.570118926850708e-34, True)
# ('PCMCI', 'PCMCI-GPDC', 1.350165460418503e-28, True)
# ('GRANGER', 'VAR', 1.2506145819297873e-17, True)
# ('MVGC', 'PCMCI', 1.3307573132554746e-13, True)
# ('DYNOTEARS', 'VAR', 0.001383416950178904, True)
# ('PCMCI', 'VARLINGAM', 0.005703511423686156, True)
# ('MVGC', 'VARLINGAM', 0.045904632236153854, False)
# ('DYNOTEARS', 'GRANGER', 0.07452104910841564, False)
# Index(['GRANGER', 'DYNOTEARS', 'VAR', 'PCMCI-GPDC', 'PCMCI', 'VARLINGAM',
#        'MVGC', 'TD2C'],
#       dtype='object')
# [0, 1]
# [5, 6]
#
# Generating Precision CD plot...
# ['VAR' 'VARLINGAM' 'PCMCI' 'MVGC' 'PCMCI-GPDC' 'GRANGER' 'DYNOTEARS'
#  'TD2C']
#         Model  count
# 0   DYNOTEARS   1080
# 1     GRANGER   1080
# 2        MVGC   1080
# 3       PCMCI   1080
# 4  PCMCI-GPDC   1080
# 5        TD2C   1080
# 6         VAR   1080
# 7   VARLINGAM   1080
# [[       nan        nan        nan ...        nan        nan        nan]
#  [0.16216216 0.22857143        nan ...        nan        nan 0.15384615]
#  [0.66666667 0.75555556 0.96774194 ... 1.         1.         0.75      ]
#  ...
#  [0.68181818 0.72727273 0.71794872 ... 0.83333333 0.66666667 0.5625    ]
#  [0.27272727 0.34782609 0.11764706 ...        nan        nan 0.5       ]
#  [0.56410256 0.54545455 0.74285714 ... 0.90909091 0.82352941 0.54545455]]
# DYNOTEARS       4.0
# GRANGER         0.0
# MVGC          130.0
# PCMCI          97.0
# PCMCI-GPDC    111.0
# TD2C          621.0
# VAR             0.0
# VARLINGAM      27.0
# dtype: float64
# GRANGER       6.612661
# VAR           6.025890
# DYNOTEARS     4.885993
# VARLINGAM     3.809349
# PCMCI-GPDC    3.060811
# MVGC          2.898200
# PCMCI         2.871111
# TD2C          2.041204
# dtype: float64
# ('DYNOTEARS', 'GRANGER', nan, False)
# ('DYNOTEARS', 'MVGC', nan, False)
# ('DYNOTEARS', 'PCMCI', nan, False)
# ('DYNOTEARS', 'PCMCI-GPDC', nan, False)
# ('DYNOTEARS', 'TD2C', nan, False)
# ('DYNOTEARS', 'VAR', nan, False)
# ('DYNOTEARS', 'VARLINGAM', nan, False)
# ('GRANGER', 'MVGC', nan, False)
# ('GRANGER', 'PCMCI', nan, False)
# ('GRANGER', 'PCMCI-GPDC', nan, False)
# ('GRANGER', 'TD2C', nan, False)
# ('GRANGER', 'VAR', nan, False)
# ('GRANGER', 'VARLINGAM', nan, False)
# ('MVGC', 'PCMCI', nan, False)
# ('MVGC', 'PCMCI-GPDC', nan, False)
# ('MVGC', 'TD2C', nan, False)
# ('MVGC', 'VAR', nan, False)
# ('MVGC', 'VARLINGAM', nan, False)
# ('PCMCI', 'PCMCI-GPDC', nan, False)
# ('PCMCI', 'TD2C', nan, False)
# ('PCMCI', 'VAR', nan, False)
# ('PCMCI', 'VARLINGAM', nan, False)
# ('PCMCI-GPDC', 'TD2C', nan, False)
# ('PCMCI-GPDC', 'VAR', nan, False)
# ('PCMCI-GPDC', 'VARLINGAM', nan, False)
# ('TD2C', 'VAR', nan, False)
# ('TD2C', 'VARLINGAM', nan, False)
# ('VAR', 'VARLINGAM', nan, False)
# Index(['GRANGER', 'VAR', 'DYNOTEARS', 'VARLINGAM', 'PCMCI-GPDC', 'MVGC',
#        'PCMCI', 'TD2C'],
#       dtype='object')
# [0, 1, 2, 3, 4, 5, 6, 7]
#
# Generating Precision CD plot...
# ['VAR' 'VARLINGAM' 'PCMCI' 'MVGC' 'PCMCI-GPDC' 'GRANGER' 'DYNOTEARS'
#  'TD2C']
#         Model  count
# 0   DYNOTEARS   1080
# 1     GRANGER   1080
# 2        MVGC   1080
# 3       PCMCI   1080
# 4  PCMCI-GPDC   1080
# 5        TD2C   1080
# 6         VAR   1080
# 7   VARLINGAM   1080
# [[0.5        0.5        0.5        ... 0.5        0.5        0.5       ]
#  [0.44120763 0.49707602 0.41525424 ... 0.49285714 0.41791045 0.49747475]
#  [0.85010593 0.88450292 0.96875    ... 1.         1.         0.95454545]
#  ...
#  [0.85858051 0.85672515 0.86122881 ... 0.98571429 0.94029851 0.89393939]
#  [0.56832627 0.60233918 0.53125    ... 0.48571429 0.49253731 0.69949495]
#  [0.74205508 0.72368421 0.85540254 ... 0.99285714 0.92257463 0.88636364]]
# DYNOTEARS       4.0
# GRANGER         0.0
# MVGC          130.0
# PCMCI          83.0
# PCMCI-GPDC     76.0
# TD2C          665.0
# VAR             0.0
# VARLINGAM      33.0
# dtype: float64
# GRANGER       7.283796
# DYNOTEARS     5.878241
# VAR           5.838426
# VARLINGAM     4.248148
# PCMCI-GPDC    3.857870
# PCMCI         3.613426
# MVGC          3.306944
# TD2C          1.973148
# dtype: float64
# ('GRANGER', 'TD2C', 3.061250894718136e-178, True)
# ('TD2C', 'VAR', 3.1817419197953564e-178, True)
# ('DYNOTEARS', 'TD2C', 6.043545016466366e-178, True)
# ('GRANGER', 'MVGC', 1.5991452504749277e-166, True)
# ('GRANGER', 'PCMCI-GPDC', 2.91337908052627e-157, True)
# ('GRANGER', 'PCMCI', 1.342004675775795e-155, True)
# ('GRANGER', 'VARLINGAM', 2.008349754903815e-152, True)
# ('MVGC', 'VAR', 1.607418999517871e-143, True)
# ('GRANGER', 'VAR', 2.040882059848247e-142, True)
# ('DYNOTEARS', 'MVGC', 2.5155986310580247e-137, True)
# ('PCMCI-GPDC', 'VAR', 4.995403938112711e-134, True)
# ('PCMCI', 'VAR', 8.731018662598489e-133, True)
# ('DYNOTEARS', 'GRANGER', 7.1268130095170806e-130, True)
# ('VAR', 'VARLINGAM', 4.724644551673035e-128, True)
# ('DYNOTEARS', 'PCMCI-GPDC', 1.6533426177109196e-127, True)
# ('DYNOTEARS', 'PCMCI', 4.3602375058534935e-127, True)
# ('DYNOTEARS', 'VARLINGAM', 1.9717293368822614e-122, True)
# ('TD2C', 'VARLINGAM', 1.439207925599418e-107, True)
# ('PCMCI-GPDC', 'TD2C', 1.9894340908135534e-81, True)
# ('PCMCI', 'TD2C', 1.2274723511702102e-71, True)
# ('MVGC', 'TD2C', 5.861048371513443e-68, True)
# ('MVGC', 'VARLINGAM', 2.355794343930488e-41, True)
# ('PCMCI', 'VARLINGAM', 1.4845080289673356e-34, True)
# ('MVGC', 'PCMCI-GPDC', 8.083450944995208e-17, True)
# ('PCMCI', 'PCMCI-GPDC', 1.1217704711504789e-10, True)
# ('PCMCI-GPDC', 'VARLINGAM', 1.688190738486815e-09, True)
# ('MVGC', 'PCMCI', 8.214213980739167e-05, True)
# ('DYNOTEARS', 'VAR', 0.00041718376713806163, True)
# Index(['GRANGER', 'DYNOTEARS', 'VAR', 'VARLINGAM', 'PCMCI-GPDC', 'PCMCI',
#        'MVGC', 'TD2C'],
#       dtype='object')
#
# Generating Precision CD plot...
# ['VAR' 'VARLINGAM' 'PCMCI' 'MVGC' 'PCMCI-GPDC' 'GRANGER' 'DYNOTEARS'
#  'TD2C']
#         Model  count
# 0   DYNOTEARS   1080
# 1     GRANGER   1080
# 2        MVGC   1080
# 3       PCMCI   1080
# 4  PCMCI-GPDC   1080
# 5        TD2C   1080
# 6         VAR   1080
# 7   VARLINGAM   1080
# [[0.78666667 0.76       0.78666667 ... 0.93333333 0.89333333 0.88      ]
#  [0.58666667 0.64       0.65333333 ... 0.92       0.74666667 0.70666667]
#  [0.8        0.85333333 0.98666667 ... 1.         1.         0.92      ]
#  ...
#  [0.81333333 0.84       0.85333333 ... 0.97333333 0.89333333 0.81333333]
#  [0.78666667 0.8        0.8        ... 0.90666667 0.88       0.89333333]
#  [0.77333333 0.66666667 0.88       ... 0.98666667 0.96       0.8       ]]
# DYNOTEARS     114.0
# GRANGER         3.0
# MVGC          141.0
# PCMCI         105.0
# PCMCI-GPDC    122.0
# TD2C          212.0
# VAR            64.0
# VARLINGAM      28.0
# dtype: float64
# GRANGER       6.932407
# VARLINGAM     5.275926
# DYNOTEARS     4.591204
# VAR           4.519907
# TD2C          4.231944
# PCMCI         3.592593
# MVGC          3.524074
# PCMCI-GPDC    3.331944
# dtype: float64
# ('GRANGER', 'VAR', 1.9477507960994466e-173, True)
# ('GRANGER', 'MVGC', 8.18222426584037e-158, True)
# ('GRANGER', 'PCMCI-GPDC', 1.6656207523888675e-148, True)
# ('GRANGER', 'PCMCI', 9.16508295117489e-138, True)
# ('GRANGER', 'TD2C', 8.680458470407817e-108, True)
# ('PCMCI-GPDC', 'VARLINGAM', 1.1839873019824717e-96, True)
# ('PCMCI', 'VARLINGAM', 2.9451411535992566e-89, True)
# ('MVGC', 'VARLINGAM', 1.7280410590487415e-74, True)
# ('DYNOTEARS', 'GRANGER', 3.107736487703331e-67, True)
# ('DYNOTEARS', 'PCMCI-GPDC', 5.930614079339343e-60, True)
# ('PCMCI-GPDC', 'VAR', 8.869696808778891e-54, True)
# ('GRANGER', 'VARLINGAM', 3.8009869653329066e-51, True)
# ('TD2C', 'VARLINGAM', 1.0670318963084252e-46, True)
# ('DYNOTEARS', 'PCMCI', 7.2945683141508e-45, True)
# ('PCMCI', 'VAR', 2.1752549890284222e-39, True)
# ('DYNOTEARS', 'MVGC', 2.21402150816186e-33, True)
# ('MVGC', 'VAR', 1.3748562866359633e-30, True)
# ('DYNOTEARS', 'TD2C', 3.9754014335376095e-23, True)
# ('PCMCI-GPDC', 'TD2C', 2.2331939286819428e-15, True)
# ('VAR', 'VARLINGAM', 2.3890385735612686e-10, True)
# ('PCMCI', 'TD2C', 7.780252661774104e-10, True)
# ('MVGC', 'TD2C', 5.202032268603456e-09, True)
# ('TD2C', 'VAR', 2.6138075495114848e-08, True)
# ('DYNOTEARS', 'VAR', 5.313575347448698e-05, True)
# ('PCMCI', 'PCMCI-GPDC', 0.0025055084527554556, True)
# ('DYNOTEARS', 'VARLINGAM', 0.002651808258542622, True)
# ('MVGC', 'PCMCI-GPDC', 0.05127048897755182, False)
# ('MVGC', 'PCMCI', 0.6783671233833076, False)
# Index(['GRANGER', 'VARLINGAM', 'DYNOTEARS', 'VAR', 'TD2C', 'PCMCI', 'MVGC',
#        'PCMCI-GPDC'],
#       dtype='object')
# [6, 5]
# [6, 7]
#
# Script finished successfully.
