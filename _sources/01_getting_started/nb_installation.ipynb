# %% [markdown]
# # Installation & Setup
#
# To use TD2C, you need to set up the Python environment. We recommend using a virtual environment (conda or venv) to avoid conflicts.
#
# ### 1. Clone the Repository
# If you haven't already, clone the repo and navigate into it:

# %%
# %%bash
# # git clone https://github.com/gmpal/TD2C-PP.git
# # cd TD2C-PP

# %% [markdown]
# ### 2. Install Dependencies
# TD2C relies on several scientific computing libraries (`numpy`, `pandas`, `scikit-learn`) and specific causal discovery tools.
